# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavorosarionunes/Fundamentos-da-Intelig-ncia-Artificial/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula de IA

# %%
print("Olá, Mundo, estou na aula de IA")
# Out:
# Olá, Mundo, estou na aula de IA

# %% [markdown]
# IA
